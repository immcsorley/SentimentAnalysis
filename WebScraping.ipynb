# %% [markdown]
# # Web Scraping The Hill News website
# ## www.thehill.com
# The Hill is a news outlet that covers politics, policy, and government affairs in the United States. It has a reputation for providing in-depth analysis and reportng on the latest politcal developments, which makes it a valuable source of information for researchers, journalists, and politcal analysts. Specifically in this project we would like to scrape articles from different topic categories and see how the sentiment is different based off the topics. The topics included are News, Policy, Business, Opinion, Events, and Jobs. We believe that based on the topic, such as opinion, might provide a different analysis than others. Grouping artcles into categories will allow us to analyze each category independently as well as looking at all articles as well.

# %% [markdown]
# ### Web scraping

# %% [markdown]
# Libraries Needed

# %%
import os
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Entire Script for web scraping, putting each html file into a folder labeled by the category it is in
#
# Note: Takes over an hour to run
#
# The first article of many pages caused issues, so we decided to skip those articles

# %%
# Function for scraping
def scrape_section_articles(base_url, section, folder_name, start_page=1, end_page=1):
    section_url = f"{base_url}/{section}/"
    section_folder = os.path.join(folder_name, section)

    if not os.path.exists(section_folder):
        os.makedirs(section_folder)

    # This outer for loop gets the html response from each page
    for page_num in range(start_page, end_page + 1):
        page_url = f"{section_url}?page_num={page_num}"
        response = requests.get(page_url)
        soup = BeautifulSoup(response.text, 'html.parser')

        articles = soup.find_all('article', class_='archive__item')

        # This inner for loop goes into the html response from each page
        # and gets the href link for each article on the page, and then writes it to a new file in our folder

        for idx, article in enumerate(articles):
            article_anchor = article.find('a')
            if article_anchor and article_anchor['href']:
                article_link = article_anchor['href']
                if not article_link.startswith('http'):
                    article_link = base_url + article_link

                article_response = requests.get(article_link)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                file_name = f"{section}_page{page_num}_article{idx+1}.html"
                with open(os.path.join(section_folder, file_name), 'w', encoding='utf-8') as f:
                    f.write(str(article_soup))

            # Some articles would not scrape correctly, specifically first article on each page, so skip these
            else:
                continue

# Setting search parameters
base_url = 'https://thehill.com'
sections = ['news', 'policy', 'business', 'opinion'] # All Categories of Articles
folder_name = "the_hill_HTML"

# Creating folder path
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Actual code to scrape using function, and printing useful information to know what went wrong
for section in sections:
    print(f"Scraping articles from {section} section...")
    scrape_section_articles(base_url, section, folder_name, start_page=1, end_page=100)

print('Articles saved as HTML files in the "thehill_html" folder.')
# Out:
# Scraping articles from news section...
# Skipped article 1 on news page 1 due to missing or invalid URL.
# Skipped article 1 on news page 2 due to missing or invalid URL.
# Skipped article 1 on news page 3 due to missing or invalid URL.
# Skipped article 1 on news page 4 due to missing or invalid URL.
# Skipped article 1 on news page 5 due to missing or invalid URL.
# Skipped article 1 on news page 6 due to missing or invalid URL.
# Skipped article 1 on news page 7 due to missing or invalid URL.
# Skipped article 1 on news page 8 due to missing or invalid URL.
# Skipped article 1 on news page 9 due to missing or invalid URL.
# Skipped article 1 on news page 10 due to missing or invalid URL.
# Skipped article 1 on news page 11 due to missing or invalid URL.
# Skipped article 1 on news page 12 due to missing or invalid URL.
# Skipped article 1 on news page 13 due to missing or invalid URL.
# Skipped article 1 on news page 14 due to missing or invalid URL.
# Skipped article 1 on news page 15 due to missing or invalid URL.
# Skipped article 1 on news page 16 due to missing or invalid URL.
# Skipped article 1 on news page 17 due to missing or invalid URL.
# Skipped article 1 on news page 18 due to missing or invalid URL.
# Skipped article 1 on news page 19 due to missing or invalid URL.
# Skipped article 1 on news page 20 due to missing or invalid URL.
# Skipped article 1 on news page 21 due to missing or invalid URL.
# Skipped article 1 on news page 22 due to missing or invalid URL.
# Skipped article 1 on news page 23 due to missing or invalid URL.
# Skipped article 1 on news page 24 due to missing or invalid URL.
# Skipped article 1 on news page 25 due to missing or invalid URL.
# Skipped article 1 on news page 26 due to missing or invalid URL.
# Skipped article 1 on news page 27 due to missing or invalid URL.
# Skipped article 1 on news page 28 due to missing or invalid URL.
# Skipped article 1 on news page 29 due to missing or invalid URL.
# Skipped article 1 on news page 30 due to missing or invalid URL.
# Skipped article 1 on news page 31 due to missing or invalid URL.
# Skipped article 1 on news page 32 due to missing or invalid URL.
# Skipped article 1 on news page 33 due to missing or invalid URL.
# Skipped article 1 on news page 34 due to missing or invalid URL.
# Skipped article 1 on news page 35 due to missing or invalid URL.
# Skipped article 1 on news page 36 due to missing or invalid URL.
# Skipped article 1 on news page 37 due to missing or invalid URL.
# Skipped article 1 on news page 38 due to missing or invalid URL.
# Skipped article 1 on news page 39 due to missing or invalid URL.
# Skipped article 1 on news page 40 due to missing or invalid URL.
# Skipped article 1 on news page 41 due to missing or invalid URL.
# Skipped article 1 on news page 42 due to missing or invalid URL.
# Skipped article 1 on news page 43 due to missing or invalid URL.
# Skipped article 1 on news page 44 due to missing or invalid URL.
# Skipped article 1 on news page 45 due to missing or invalid URL.
# Skipped article 1 on news page 46 due to missing or invalid URL.
# Skipped article 1 on news page 47 due to missing or invalid URL.
# Skipped article 1 on news page 48 due to missing or invalid URL.
# Skipped article 1 on news page 49 due to missing or invalid URL.
# Skipped article 1 on news page 50 due to missing or invalid URL.
# Skipped article 1 on news page 51 due to missing or invalid URL.
# Skipped article 1 on news page 52 due to missing or invalid URL.
# Skipped article 1 on news page 53 due to missing or invalid URL.
# Skipped article 1 on news page 54 due to missing or invalid URL.
# Skipped article 1 on news page 55 due to missing or invalid URL.
# Skipped article 1 on news page 56 due to missing or invalid URL.
# Skipped article 1 on news page 57 due to missing or invalid URL.
# Skipped article 1 on news page 58 due to missing or invalid URL.
# Skipped article 1 on news page 59 due to missing or invalid URL.
# Skipped article 1 on news page 60 due to missing or invalid URL.
# Skipped article 1 on news page 61 due to missing or invalid URL.
# Skipped article 1 on news page 62 due to missing or invalid URL.
# Skipped article 1 on news page 63 due to missing or invalid URL.
# Skipped article 1 on news page 64 due to missing or invalid URL.
# Skipped article 1 on news page 65 due to missing or invalid URL.
# Skipped article 1 on news page 66 due to missing or invalid URL.
# Skipped article 1 on news page 67 due to missing or invalid URL.
# Skipped article 1 on news page 68 due to missing or invalid URL.
# Skipped article 1 on news page 69 due to missing or invalid URL.
# Skipped article 1 on news page 70 due to missing or invalid URL.
# Skipped article 1 on news page 71 due to missing or invalid URL.
# Skipped article 1 on news page 72 due to missing or invalid URL.
# Skipped article 1 on news page 73 due to missing or invalid URL.
# Skipped article 1 on news page 74 due to missing or invalid URL.
# Skipped article 1 on news page 75 due to missing or invalid URL.
# Skipped article 1 on news page 76 due to missing or invalid URL.
# Skipped article 1 on news page 77 due to missing or invalid URL.
# Skipped article 1 on news page 78 due to missing or invalid URL.
# Skipped article 1 on news page 79 due to missing or invalid URL.
# Skipped article 1 on news page 80 due to missing or invalid URL.
# Skipped article 1 on news page 81 due to missing or invalid URL.
# Skipped article 1 on news page 82 due to missing or invalid URL.
# Skipped article 1 on news page 83 due to missing or invalid URL.
# Skipped article 1 on news page 84 due to missing or invalid URL.
# Skipped article 1 on news page 85 due to missing or invalid URL.
# Skipped article 1 on news page 86 due to missing or invalid URL.
# Skipped article 1 on news page 87 due to missing or invalid URL.
# Skipped article 1 on news page 88 due to missing or invalid URL.
# Skipped article 1 on news page 89 due to missing or invalid URL.
# Skipped article 1 on news page 90 due to missing or invalid URL.
# Skipped article 1 on news page 91 due to missing or invalid URL.
# Skipped article 1 on news page 92 due to missing or invalid URL.
# Skipped article 1 on news page 93 due to missing or invalid URL.
# Skipped article 1 on news page 94 due to missing or invalid URL.
# Skipped article 1 on news page 95 due to missing or invalid URL.
# Skipped article 1 on news page 96 due to missing or invalid URL.
# Skipped article 1 on news page 97 due to missing or invalid URL.
# Skipped article 1 on news page 98 due to missing or invalid URL.
# Skipped article 1 on news page 99 due to missing or invalid URL.
# Skipped article 1 on news page 100 due to missing or invalid URL.
# Scraping articles from policy section...
# Skipped article 1 on policy page 1 due to missing or invalid URL.
# Skipped article 1 on policy page 2 due to missing or invalid URL.
# Skipped article 1 on policy page 3 due to missing or invalid URL.
# Skipped article 1 on policy page 4 due to missing or invalid URL.
# Skipped article 1 on policy page 5 due to missing or invalid URL.
# Skipped article 1 on policy page 6 due to missing or invalid URL.
# Skipped article 1 on policy page 7 due to missing or invalid URL.
# Skipped article 1 on policy page 8 due to missing or invalid URL.
# Skipped article 1 on policy page 9 due to missing or invalid URL.
# Skipped article 1 on policy page 10 due to missing or invalid URL.
# Skipped article 1 on policy page 11 due to missing or invalid URL.
# Skipped article 1 on policy page 12 due to missing or invalid URL.
# Skipped article 1 on policy page 13 due to missing or invalid URL.
# Skipped article 1 on policy page 14 due to missing or invalid URL.
# Skipped article 1 on policy page 15 due to missing or invalid URL.
# Skipped article 1 on policy page 16 due to missing or invalid URL.
# Skipped article 1 on policy page 17 due to missing or invalid URL.
# Skipped article 1 on policy page 18 due to missing or invalid URL.
# Skipped article 1 on policy page 19 due to missing or invalid URL.
# Skipped article 1 on policy page 20 due to missing or invalid URL.
# Skipped article 1 on policy page 21 due to missing or invalid URL.
# Skipped article 1 on policy page 22 due to missing or invalid URL.
# Skipped article 1 on policy page 23 due to missing or invalid URL.
# Skipped article 1 on policy page 24 due to missing or invalid URL.
# Skipped article 1 on policy page 25 due to missing or invalid URL.
# Skipped article 1 on policy page 26 due to missing or invalid URL.
# Skipped article 1 on policy page 27 due to missing or invalid URL.
# Skipped article 1 on policy page 28 due to missing or invalid URL.
# Skipped article 1 on policy page 29 due to missing or invalid URL.
# Skipped article 1 on policy page 30 due to missing or invalid URL.
# Skipped article 1 on policy page 31 due to missing or invalid URL.
# Skipped article 1 on policy page 32 due to missing or invalid URL.
# Skipped article 1 on policy page 33 due to missing or invalid URL.
# Skipped article 1 on policy page 34 due to missing or invalid URL.
# Skipped article 1 on policy page 35 due to missing or invalid URL.
# Skipped article 1 on policy page 36 due to missing or invalid URL.
# Skipped article 1 on policy page 37 due to missing or invalid URL.
# Skipped article 1 on policy page 38 due to missing or invalid URL.
# Skipped article 1 on policy page 39 due to missing or invalid URL.
# Skipped article 1 on policy page 40 due to missing or invalid URL.
# Skipped article 1 on policy page 41 due to missing or invalid URL.
# Skipped article 1 on policy page 42 due to missing or invalid URL.
# Skipped article 1 on policy page 43 due to missing or invalid URL.
# Skipped article 1 on policy page 44 due to missing or invalid URL.
# Skipped article 1 on policy page 45 due to missing or invalid URL.
# Skipped article 1 on policy page 46 due to missing or invalid URL.
# Skipped article 1 on policy page 47 due to missing or invalid URL.
# Skipped article 1 on policy page 48 due to missing or invalid URL.
# Skipped article 1 on policy page 49 due to missing or invalid URL.
# Skipped article 1 on policy page 50 due to missing or invalid URL.
# Skipped article 1 on policy page 51 due to missing or invalid URL.
# Skipped article 1 on policy page 52 due to missing or invalid URL.
# Skipped article 1 on policy page 53 due to missing or invalid URL.
# Skipped article 1 on policy page 54 due to missing or invalid URL.
# Skipped article 1 on policy page 55 due to missing or invalid URL.
# Skipped article 1 on policy page 56 due to missing or invalid URL.
# Skipped article 1 on policy page 57 due to missing or invalid URL.
# Skipped article 1 on policy page 58 due to missing or invalid URL.
# Skipped article 1 on policy page 59 due to missing or invalid URL.
# Skipped article 1 on policy page 60 due to missing or invalid URL.
# Skipped article 1 on policy page 61 due to missing or invalid URL.
# Skipped article 1 on policy page 62 due to missing or invalid URL.
# Skipped article 1 on policy page 63 due to missing or invalid URL.
# Skipped article 1 on policy page 64 due to missing or invalid URL.
# Skipped article 1 on policy page 65 due to missing or invalid URL.
# Skipped article 1 on policy page 66 due to missing or invalid URL.
# Skipped article 1 on policy page 67 due to missing or invalid URL.
# Skipped article 1 on policy page 68 due to missing or invalid URL.
# Skipped article 1 on policy page 69 due to missing or invalid URL.
# Skipped article 1 on policy page 70 due to missing or invalid URL.
# Skipped article 1 on policy page 71 due to missing or invalid URL.
# Skipped article 1 on policy page 72 due to missing or invalid URL.
# Skipped article 1 on policy page 73 due to missing or invalid URL.
# Skipped article 1 on policy page 74 due to missing or invalid URL.
# Skipped article 1 on policy page 75 due to missing or invalid URL.
# Skipped article 1 on policy page 76 due to missing or invalid URL.
# Skipped article 1 on policy page 77 due to missing or invalid URL.
# Skipped article 1 on policy page 78 due to missing or invalid URL.
# Skipped article 1 on policy page 79 due to missing or invalid URL.
# Skipped article 1 on policy page 80 due to missing or invalid URL.
# Skipped article 1 on policy page 81 due to missing or invalid URL.
# Skipped article 1 on policy page 82 due to missing or invalid URL.
# Skipped article 1 on policy page 83 due to missing or invalid URL.
# Skipped article 1 on policy page 84 due to missing or invalid URL.
# Skipped article 1 on policy page 85 due to missing or invalid URL.
# Skipped article 1 on policy page 86 due to missing or invalid URL.
# Skipped article 1 on policy page 87 due to missing or invalid URL.
# Skipped article 1 on policy page 88 due to missing or invalid URL.
# Skipped article 1 on policy page 89 due to missing or invalid URL.
# Skipped article 1 on policy page 90 due to missing or invalid URL.
# Skipped article 1 on policy page 91 due to missing or invalid URL.
# Skipped article 1 on policy page 92 due to missing or invalid URL.
# Skipped article 1 on policy page 93 due to missing or invalid URL.
# Skipped article 1 on policy page 94 due to missing or invalid URL.
# Skipped article 1 on policy page 95 due to missing or invalid URL.
# Skipped article 1 on policy page 96 due to missing or invalid URL.
# Skipped article 1 on policy page 97 due to missing or invalid URL.
# Skipped article 1 on policy page 98 due to missing or invalid URL.
# Skipped article 1 on policy page 99 due to missing or invalid URL.
# Skipped article 1 on policy page 100 due to missing or invalid URL.
# Scraping articles from business section...
# Skipped article 1 on business page 1 due to missing or invalid URL.
# Skipped article 1 on business page 2 due to missing or invalid URL.
# Skipped article 1 on business page 3 due to missing or invalid URL.
# Skipped article 1 on business page 4 due to missing or invalid URL.
# Skipped article 1 on business page 5 due to missing or invalid URL.
# Skipped article 1 on business page 6 due to missing or invalid URL.
# Skipped article 1 on business page 7 due to missing or invalid URL.
# Skipped article 1 on business page 8 due to missing or invalid URL.
# Skipped article 1 on business page 9 due to missing or invalid URL.
# Skipped article 1 on business page 10 due to missing or invalid URL.
# Skipped article 1 on business page 11 due to missing or invalid URL.
# Skipped article 1 on business page 12 due to missing or invalid URL.
# Skipped article 1 on business page 13 due to missing or invalid URL.
# Skipped article 1 on business page 14 due to missing or invalid URL.
# Skipped article 1 on business page 15 due to missing or invalid URL.
# Skipped article 1 on business page 16 due to missing or invalid URL.
# Skipped article 1 on business page 17 due to missing or invalid URL.
# Skipped article 1 on business page 18 due to missing or invalid URL.
# Skipped article 1 on business page 19 due to missing or invalid URL.
# Skipped article 1 on business page 20 due to missing or invalid URL.
# Skipped article 1 on business page 21 due to missing or invalid URL.
# Skipped article 1 on business page 22 due to missing or invalid URL.
# Skipped article 1 on business page 23 due to missing or invalid URL.
# Skipped article 1 on business page 24 due to missing or invalid URL.
# Skipped article 1 on business page 25 due to missing or invalid URL.
# Skipped article 1 on business page 26 due to missing or invalid URL.
# Skipped article 1 on business page 27 due to missing or invalid URL.
# Skipped article 1 on business page 28 due to missing or invalid URL.
# Skipped article 1 on business page 29 due to missing or invalid URL.
# Skipped article 1 on business page 30 due to missing or invalid URL.
# Skipped article 1 on business page 31 due to missing or invalid URL.
# Skipped article 1 on business page 32 due to missing or invalid URL.
# Skipped article 1 on business page 33 due to missing or invalid URL.
# Skipped article 1 on business page 34 due to missing or invalid URL.
# Skipped article 1 on business page 35 due to missing or invalid URL.
# Skipped article 1 on business page 36 due to missing or invalid URL.
# Skipped article 1 on business page 37 due to missing or invalid URL.
# Skipped article 1 on business page 38 due to missing or invalid URL.
# Skipped article 1 on business page 39 due to missing or invalid URL.
# Skipped article 1 on business page 40 due to missing or invalid URL.
# Skipped article 1 on business page 41 due to missing or invalid URL.
# Skipped article 1 on business page 42 due to missing or invalid URL.
# Skipped article 1 on business page 43 due to missing or invalid URL.
# Skipped article 1 on business page 44 due to missing or invalid URL.
# Skipped article 1 on business page 45 due to missing or invalid URL.
# Skipped article 1 on business page 46 due to missing or invalid URL.
# Skipped article 1 on business page 47 due to missing or invalid URL.
# Skipped article 1 on business page 48 due to missing or invalid URL.
# Skipped article 1 on business page 49 due to missing or invalid URL.
# Skipped article 1 on business page 50 due to missing or invalid URL.
# Skipped article 1 on business page 51 due to missing or invalid URL.
# Skipped article 1 on business page 52 due to missing or invalid URL.
# Skipped article 1 on business page 53 due to missing or invalid URL.
# Skipped article 1 on business page 54 due to missing or invalid URL.
# Skipped article 1 on business page 55 due to missing or invalid URL.
# Skipped article 1 on business page 56 due to missing or invalid URL.
# Skipped article 1 on business page 57 due to missing or invalid URL.
# Skipped article 1 on business page 58 due to missing or invalid URL.
# Skipped article 1 on business page 59 due to missing or invalid URL.
# Skipped article 1 on business page 60 due to missing or invalid URL.
# Skipped article 1 on business page 61 due to missing or invalid URL.
# Skipped article 1 on business page 62 due to missing or invalid URL.
# Skipped article 1 on business page 63 due to missing or invalid URL.
# Skipped article 1 on business page 64 due to missing or invalid URL.
# Skipped article 1 on business page 65 due to missing or invalid URL.
# Skipped article 1 on business page 66 due to missing or invalid URL.
# Skipped article 1 on business page 67 due to missing or invalid URL.
# Skipped article 1 on business page 68 due to missing or invalid URL.
# Skipped article 1 on business page 69 due to missing or invalid URL.
# Skipped article 1 on business page 70 due to missing or invalid URL.
# Skipped article 1 on business page 71 due to missing or invalid URL.
# Skipped article 1 on business page 72 due to missing or invalid URL.
# Skipped article 1 on business page 73 due to missing or invalid URL.
# Skipped article 1 on business page 74 due to missing or invalid URL.
# Skipped article 1 on business page 75 due to missing or invalid URL.
# Skipped article 1 on business page 76 due to missing or invalid URL.
# Skipped article 1 on business page 77 due to missing or invalid URL.
# Skipped article 1 on business page 78 due to missing or invalid URL.
# Skipped article 1 on business page 79 due to missing or invalid URL.
# Skipped article 1 on business page 80 due to missing or invalid URL.
# Skipped article 1 on business page 81 due to missing or invalid URL.
# Skipped article 1 on business page 82 due to missing or invalid URL.
# Skipped article 1 on business page 83 due to missing or invalid URL.
# Skipped article 1 on business page 84 due to missing or invalid URL.
# Skipped article 1 on business page 85 due to missing or invalid URL.
# Skipped article 1 on business page 86 due to missing or invalid URL.
# Skipped article 1 on business page 87 due to missing or invalid URL.
# Skipped article 1 on business page 88 due to missing or invalid URL.
# Skipped article 1 on business page 89 due to missing or invalid URL.
# Skipped article 1 on business page 90 due to missing or invalid URL.
# Skipped article 1 on business page 91 due to missing or invalid URL.
# Skipped article 1 on business page 92 due to missing or invalid URL.
# Skipped article 1 on business page 93 due to missing or invalid URL.
# Skipped article 1 on business page 94 due to missing or invalid URL.
# Skipped article 1 on business page 95 due to missing or invalid URL.
# Skipped article 1 on business page 96 due to missing or invalid URL.
# Skipped article 1 on business page 97 due to missing or invalid URL.
# Skipped article 1 on business page 98 due to missing or invalid URL.
# Skipped article 1 on business page 99 due to missing or invalid URL.
# Skipped article 1 on business page 100 due to missing or invalid URL.
# Scraping articles from opinion section...
# Articles saved as HTML files in the "thehill_html" folder.

# %% [markdown]
# ### Finding how many articles scraped

# %%
folder_name = "the_hill_HTML"
total_files = 0

# Iterate through each subfolder in the folder
for subfolder in os.listdir(folder_name):
    subfolder_path = os.path.join(folder_name, subfolder)

    # Check if the subfolder_path is a directory
    if os.path.isdir(subfolder_path):
        subfolder_files = 0
        # Iterate through each file in the subfolder
        for file in os.listdir(subfolder_path):
            file_path = os.path.join(subfolder_path, file)

            # Check if the file_path is a file, not a directory
            if os.path.isfile(file_path):
                subfolder_files += 1

        print(f'There are {subfolder_files} files in the "{subfolder}" subfolder.')
        total_files += subfolder_files

print(f'There are {total_files} files in total in the "{folder_name}" folder.')
# Out:
# There are 1897 files in the "business" subfolder.
# There are 3400 files in the "opinion" subfolder.
# There are 1600 files in the "policy" subfolder.
# There are 1600 files in the "news" subfolder.
# There are 8497 files in total in the "the_hill_HTML" folder.
